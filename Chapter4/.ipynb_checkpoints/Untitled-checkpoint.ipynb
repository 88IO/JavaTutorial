# %%
import sympy

sympy.init_printing()

sympy.var("x")

f = sympy.log(x)

sympy.display(f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4ff65660c52a> in <module>
#       5 f = sympy.var("x")
#       6
# ----> 7 sympy.display(f)
#
# AttributeError: module 'sympy' has no attribute 'display'
